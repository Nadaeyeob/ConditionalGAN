# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
import random
import time
from IPython.display import clear_output
import os
import glob

# %%
drawing_list = []
drawing_cycle_gan = cv.imread('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\drawing_cycle_gan.jpg')
drawing_target = cv.imread('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\drawing_target.jpg')
drawing_c_gan_1 = cv.imread('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\drawing_c_gan_1.jpg')
drawing_c_gan_3 = cv.imread('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\drawing_c_gan_3.jpg')

drawing_list.append(drawing_cycle_gan)
drawing_list.append(drawing_target)
drawing_list.append(drawing_c_gan_1)
drawing_list.append(drawing_c_gan_3)

# %%
# Drawing은 Segmentation 진행 후 Resize 필요

def drawing_segmentation(img):
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    # Kernel Size 조절해가면서 시도 필요
    k = cv.getStructuringElement(cv.MORPH_RECT, (3,3))
    erosion = cv.erode(gray,k)
    ret, thr = cv.threshold(erosion, 0, 255, cv.THRESH_OTSU)
    cnt, label = cv.connectedComponents(thr)
    bg_img = np.zeros_like(img)
    
    return bg_img, cnt, label, erosion, gray

# %%
colors = []
for n, img in enumerate(drawing_list):
    bg_img, cnt, label, erosion, gray = drawing_segmentation(img)
   
    for i in range(cnt):
        if n == 0:
            color = [int(j) for j in np.random.randint(0,255,3)]
            bg_img[label==i] = color
            colors.append(color)
        else:
            bg_img[label==i] = colors[i]
    
    if max(bg_img.shape)>256:
        scale = 256/max(bg_img.shape)
        bg_img = cv.resize(bg_img, dsize=(256,256))
        img = img / 127.5 - 1
    
    drawing_list[n] = bg_img

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 4)
for i in range(len(drawing_list)):
    axs[i].imshow(drawing_list[i])

# %%
dir_list = os.listdir('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\')

# %%
cycle_gan_list = [file for file in dir_list if file.startswith("cycle_gan") and file.endswith('.jpg')]
c_gan_1_list = [file for file in dir_list if file.startswith("c_gan_1") and file.endswith('.jpg')]
c_gan_3_list = [file for file in dir_list if file.startswith("c_gan_3") and file.endswith('.jpg')]
c_gan_2_list = [file for file in dir_list if file.startswith("c_gan_2") and file.endswith('.jpg')]

# %%
def preprocessing_img(path):
    img = cv.imread(path)
    if max(img.shape)>256:
        scale = 256/max(img.shape)
        img = cv.resize(img, dsize=(256,256))
        img = img / 127.5 - 1    
    return img

# %%
def preprocessing_list(lists):
    for i, address in enumerate(lists):
        if address.endswith('.npy'):
            pass
        else:
            path = os.path.join("C:\\Users\\sw991\\project\\230501_GAN\\image_data", address)
            img = preprocessing_img(path)
            print(path)

            lists[i] = img

# %%
preprocessing_list(cycle_gan_list)
preprocessing_list(c_gan_1_list)
preprocessing_list(c_gan_3_list)

# %%
def data_augmentation(drawing, real):
        
    x1 = random.randint(0,20)
    x2 = x1 + 235

    y1 = random.randint(0,20)
    y2 = y1 + 235
    new_drawing = drawing[y1:y2,x1:x2,:]
    new_real = real[y1:y2,x1:x2,:]

    new_drawing = cv.resize(new_drawing, dsize=(drawing.shape[1], drawing.shape[0]))
    new_real = cv.resize(new_real, dsize=(drawing.shape[1], drawing.shape[0]))
        
    (h, w) = drawing.shape[:2]
    (cx, cy) = (w/2, h/2)
    angle = np.random.randint(0,360)
    matrix = cv.getRotationMatrix2D((cx,cy),angle,1.0)
    new_drawing = cv.warpAffine(new_drawing, matrix, (w,h))
    new_real = cv.warpAffine(new_real, matrix, (w,h))
    
    mode = random.randint(-1,2)
    if mode != 2:
        new_drawing = cv.flip(new_drawing, mode)
        new_real = cv.flip(new_real, mode)
    else:
        pass

    return new_drawing, new_real

# %%
def list_augmentation(drawings, reals):
    for iteration in range(300):
        idx = np.random.randint(0,len(reals))
        drawing, real = data_augmentation(drawings, reals[idx])

        drawing = np.expand_dims(drawing, axis = 0)
        real = np.expand_dims(real, axis = 0)
        if iteration == 0:
            drawing_numpy = drawing
            real_numpy = real
        else:
            drawing_numpy = np.vstack((drawing_numpy, drawing))
            real_numpy = np.vstack((real_numpy, real))
    return drawing_numpy, real_numpy

# %%
a,b = list_augmentation(drawing_list[0], cycle_gan_list)
c,d = list_augmentation(drawing_list[2], c_gan_1_list)
e,f = list_augmentation(drawing_list[3], c_gan_3_list)

# %%
print(a.shape, b.shape, c.shape, d.shape, e.shape, f.shape)

# %%
np.save('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\cycle_gan_drawing',a)
np.save('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\cycle_gan_img',b)

np.save('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\c_gan_1_drawing',c)
np.save('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\c_gan_1_img',d)

np.save('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\c_gan_3_drawing',e)
np.save('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\c_gan_3_img',f)

np.save('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\drawing_list',drawing_list)

# %%
# cycle_gan_drawing = np.load('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\cycle_gan_drawing.npy')
cycle_gan_img = np.load('image_data/cycle_gan_img.npy')

# c_gan_1_drawing = np.load('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\c_gan_1_drawing.npy')
c_gan_1_img = np.load('image_data/c_gan_1_img.npy')

# c_gan_3_drawing = np.load('C:\\Users\\sw991\\project\\230501_GAN\\image_data\\c_gan_3_drawing.npy')
c_gan_3_img = np.load('image_data/c_gan_3_img.npy')

# %%
all_digit = np.vstack((cycle_gan_img, c_gan_1_img))
all_digit = np.vstack((all_digit, c_gan_3_img))
print(all_digit.shape)
# Out:
# (900, 256, 256, 3)

# %%
label_0 = np.expand_dims(np.zeros((300,)), axis = -1)
label_1 = np.expand_dims(np.ones((300,)), axis = -1)
label_3 = np.expand_dims(np.ones((300,)) * 3, axis = -1)

all_label = np.vstack((label_0, label_1))
all_label = np.vstack((all_label, label_3))
print(all_label.shape)
# Out:
# (900, 1)

# %%
all_data = [all_digit, all_label]

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LeakyReLU, Conv2D, Conv2DTranspose, UpSampling2D, Input, Concatenate, Activation, Embedding
from tensorflow.keras.layers import Dense, Reshape, BatchNormalization, Flatten, Multiply
from tensorflow_addons.layers import InstanceNormalization
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
img_size = 256
z_dim = 128
image_shape = (image_size, image_size, 3)

# %%
# generator의 Input이 z_dim + label's channel 임을 확인
def Generator(z_dim):
    input_tensor = Input(shape=(z_dim+1,))
    x = Dense(256*8*8)(input_tensor)
    x = Reshape((8,8,256))(x)
    
    # 16 * 16 * 128
    x = Conv2DTranspose(128, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha = 0.01)(x)

    # 32 * 32 * 64
    x = Conv2DTranspose(64, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha = 0.01)(x)

    # 64 * 64 * 32
    x = Conv2DTranspose(32, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha = 0.01)(x)

    # 128 * 128 * 16
    x = Conv2DTranspose(16, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha = 0.01)(x)
    
    # 256 * 256 * 8
    x = Conv2DTranspose(8, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha = 0.01)(x)
    
    # 256 * 256 * 3
    x = Conv2DTranspose(3, kernel_size = 3, strides = 1, 
                        padding = 'same')(x)
    output = Activation('tanh')(x)
    
    model = Model(input_tensor, output)
    
    return model

# %%
# Discriminator의 Input이 (Img_size, Img_size, RGB + label's channel) 임을 확인
def Discriminator():
    input_tensor = Input(shape=(img_size,img_size,4))
    
    # 128 * 128 * 8
    x = Conv2D(8, kernel_size = 3, strides = 2, padding = 'same')(input_tensor)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    # 64 * 64 * 16
    x = Conv2D(16, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    # 32 * 32 * 32
    x = Conv2D(16, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    # 16 * 16 * 64
    x = Conv2D(16, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    # 8 * 8 * 128
    x = Conv2D(16, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    x = Flatten()(x)
    output = layers.Dense(1, activation='sigmoid')(x)
    
    model = Model(input_tensor, output)
    return model

# %%
generator = Generator(z_dim)
discriminator = Discriminator()
# Out:
# Metal device set to: Apple M1
# 2023-05-10 15:38:17.882047: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-05-10 15:38:17.882294: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class ConditionalGAN(keras.Model):
    def __init__(self, discriminator, generator, z_dim):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.z_dim = z_dim
        self.gen_loss_tracker = keras.metrics.Mean()
        self.disc_loss_tracker = keras.metrics.Mean()
        
    @property
    def metrics(self):
        return [self.gen_loss_tracker, self.disc_loss_tracker]
    
    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        
    # Data 넣어줬을 때 Shape[0]이 곧 Batch_size로 써도 가능
    @tf.function
    def train_step(self, data, batch_size ):
        raw_real_imgs = data[0]
        raw_labels = data[1]
        # data 항목에 One-hot encoding 진행하여 Input
        # 소수점 등 집어넣기 위해 일단 OH encoding 미실시
        
        idx = np.random.randint(0,raw_real_imgs.shape[0],batch_size)
        real_imgs = raw_real_imgs[idx]
        labels = raw_labels[idx]
        
                
        # label > 256*256*1 size Layer로 만들어 concat 진행
        img_labels = tf.repeat(labels, repeats = [img_size * img_size])
        img_labels = tf.reshape(img_labels, shape=(-1, img_size,
                                                  img_size, 1))
        img_labels = tf.cast(img_labels, tf.float32)
        
        # discriminator 훈련 진행
        z_dim_vector = tf.random.normal(shape = (batch_size, self.z_dim))
        random_vector_labels = tf.concat([z_dim_vector, labels], axis = 1)
        #random_vector_labels의 shape이 (Batch_size, channel)이고, Generator Input과 같아야함
    
        generated_imgs = self.generator(random_vector_labels)


        fake_imgs_and_labels = tf.concat([generated_imgs, img_labels], axis = -1)
        real_imgs_and_labels = tf.concat([real_imgs, img_labels], axis = -1)
        
        combined_imgs = tf.concat([fake_imgs_and_labels, real_imgs_and_labels], 
                                 axis = 0)
        
        combined_labels = tf.concat([tf.ones((batch_size,1)), tf.zeros((batch_size,1))],
                          axis = 0)
        
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_imgs)
            d_loss = self.loss_fn(combined_labels, predictions)
            
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(zip(grads, 
                                             self.discriminator.trainable_weights))
        
        
        # generator 훈련 할 때 Discriminator를 훈련하지 않는 것인지 확인 필요
        z_dim_vector = tf.random.normal(shape = (batch_size, self.z_dim))
        random_vector_labels = tf.concat([z_dim_vector, labels], axis = 1)
        misleading_labels = tf.zeros((batch_size,1))
        
        with tf.GradientTape() as tape:
            fake_images = self.generator(random_vector_labels)
            fake_image_and_labels = tf.concat([fake_images, img_labels], axis = -1)
            predictions = self.discriminator(fake_image_and_labels)
            g_loss = self.loss_fn(misleading_labels, predictions)
            
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Monitor loss.
        self.gen_loss_tracker.update_state(g_loss)
        self.disc_loss_tracker.update_state(d_loss)
        return {
            "g_loss": self.gen_loss_tracker.result(),
            "d_loss": self.disc_loss_tracker.result(),
        }

# %%
cond_gan = ConditionalGAN(discriminator=discriminator, 
                          generator=generator, 
                          z_dim=z_dim)
cond_gan.compile(d_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
                 g_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
                 loss_fn=keras.losses.BinaryCrossentropy(from_logits=True))

# %%
def generate_images(model, epoch, z_dim):
    test_labels = np.array([[0],[1],[2],[3]])
    z_dim_vector = tf.random.normal(shape = (4, z_dim))
    random_vector_labels = tf.concat([z_dim_vector, test_labels], axis = 1)

    prediction = model(random_vector_labels)
    plt.figure(figsize=(24, 12))
    title = ['0', '1', '2', '3']

    for i in range(test_labels.shape[0]):
        
        plt.subplot(1, test_labels.shape[0], i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(prediction[i] * 0.5 + 0.5)
        plt.axis('off')
    plt.savefig('./image/Conditional_GAN_Image %d.png' %(epoch+1))
    # Plt.show() 전에 저장 필요
    plt.show()

# %%
epochs = 1000000
batch_size =32

# %%
for epoch in range(epochs):
    iterations = int(all_data[0].shape[0] / batch_size)
    start = time.time()

    for iteration in range(iterations):
        cond_gan.train_step(all_data, batch_size)
        
    if (epoch + 1) % 50 == 0:
        generate_images(generator, epoch, z_dim)
        cond_gan.save_weights('./checkpoints/my_checkpoint')
        
    if (epoch + 1) % 250 == 0:
        clear_output(wait=True)
        
    print ('Time taken for epoch {} is {} sec\n'.format(epoch + 1,
                                                      time.time()-start))
# Out:
# Time taken for epoch 1 is 9.023632049560547 sec
#
# Time taken for epoch 2 is 8.899950742721558 sec
#
# Time taken for epoch 3 is 8.911516189575195 sec
#
# Time taken for epoch 4 is 8.970675945281982 sec
#
# Time taken for epoch 5 is 8.896580934524536 sec
#
# Time taken for epoch 6 is 8.958397150039673 sec
#
# Time taken for epoch 7 is 8.907828092575073 sec
#
# Time taken for epoch 8 is 8.890963315963745 sec
#
# Time taken for epoch 9 is 8.916723012924194 sec
#
# Time taken for epoch 10 is 8.971459150314331 sec
#
# Time taken for epoch 11 is 8.975229024887085 sec
#
# Time taken for epoch 12 is 9.06061601638794 sec
#
# Time taken for epoch 13 is 8.960007190704346 sec
#
# Time taken for epoch 14 is 8.997384071350098 sec
#
# Time taken for epoch 15 is 8.96314001083374 sec
#
# Time taken for epoch 16 is 9.101164102554321 sec
#
# Time taken for epoch 17 is 8.924324035644531 sec
#
# Time taken for epoch 18 is 8.939043045043945 sec
#
# Time taken for epoch 19 is 9.010424137115479 sec
#
# Time taken for epoch 20 is 8.939377069473267 sec
#
# Time taken for epoch 21 is 9.06628704071045 sec
#
# Time taken for epoch 22 is 8.966322898864746 sec
#
# Time taken for epoch 23 is 9.053619146347046 sec
#
# Time taken for epoch 24 is 9.05092978477478 sec
#
# Time taken for epoch 25 is 9.065468788146973 sec
#
# Time taken for epoch 26 is 9.406071662902832 sec
#
# Time taken for epoch 27 is 9.314594030380249 sec
#
# Time taken for epoch 28 is 9.50424575805664 sec
#
# Time taken for epoch 29 is 9.232281923294067 sec
#
# Time taken for epoch 30 is 9.084756851196289 sec
#
# Time taken for epoch 31 is 9.087593793869019 sec
#
# Time taken for epoch 32 is 9.10883092880249 sec
#
# Time taken for epoch 33 is 9.114574909210205 sec
#
# Time taken for epoch 34 is 9.226763010025024 sec
#
# Time taken for epoch 35 is 9.343129873275757 sec
#
# Time taken for epoch 36 is 9.427731037139893 sec
#
# Time taken for epoch 37 is 9.56475305557251 sec
#
# Time taken for epoch 38 is 9.693359851837158 sec
#
# Time taken for epoch 39 is 9.77929425239563 sec
#
# Time taken for epoch 40 is 9.806909084320068 sec
#
# Time taken for epoch 41 is 9.886136054992676 sec
#
# Time taken for epoch 42 is 9.92505693435669 sec
#
# Time taken for epoch 43 is 9.942353010177612 sec
#
# Time taken for epoch 44 is 9.956992149353027 sec
#
# Time taken for epoch 45 is 9.946461915969849 sec
#
# Time taken for epoch 46 is 10.160774230957031 sec
#
# Time taken for epoch 47 is 10.136792182922363 sec
#
# Time taken for epoch 48 is 10.091315031051636 sec
#
# Time taken for epoch 49 is 10.045256853103638 sec
# Time taken for epoch 50 is 11.169285774230957 sec
#
# Time taken for epoch 51 is 9.901562929153442 sec
#
# Time taken for epoch 52 is 10.127817869186401 sec
#
# Time taken for epoch 53 is 10.101826190948486 sec
#
# Time taken for epoch 54 is 10.13647198677063 sec
#
# Time taken for epoch 55 is 10.126589059829712 sec
#
# Time taken for epoch 56 is 10.139943361282349 sec
#
# Time taken for epoch 57 is 10.154513120651245 sec
#
# Time taken for epoch 58 is 10.410719156265259 sec
#
# Time taken for epoch 59 is 11.193187952041626 sec
#
# Time taken for epoch 60 is 11.10881781578064 sec
#
# Time taken for epoch 61 is 10.7466139793396 sec
#
# Time taken for epoch 62 is 10.249127864837646 sec
#
# Time taken for epoch 63 is 10.225266933441162 sec
#
# Time taken for epoch 64 is 10.267077922821045 sec
#
# Time taken for epoch 65 is 10.314465999603271 sec
#
# Time taken for epoch 66 is 10.323798894882202 sec
#
# Time taken for epoch 67 is 10.349776983261108 sec
#
# Time taken for epoch 68 is 10.377689123153687 sec
#
# Time taken for epoch 69 is 10.3784499168396 sec
#
# Time taken for epoch 70 is 10.41742992401123 sec
#
# Time taken for epoch 71 is 10.43934965133667 sec
#
# Time taken for epoch 72 is 10.451429843902588 sec
#
# Time taken for epoch 73 is 10.577738046646118 sec
#
# Time taken for epoch 74 is 10.554415941238403 sec
#
# Time taken for epoch 75 is 10.5594642162323 sec
#
# Time taken for epoch 76 is 10.55656909942627 sec
#
# Time taken for epoch 77 is 10.633239984512329 sec
#
# Time taken for epoch 78 is 10.581080913543701 sec
#
# Time taken for epoch 79 is 10.595906972885132 sec
#
# Time taken for epoch 80 is 10.547070980072021 sec
#
# Time taken for epoch 81 is 10.55233883857727 sec
#
# Time taken for epoch 82 is 10.566627025604248 sec
#
# Time taken for epoch 83 is 10.597523927688599 sec
#
# Time taken for epoch 84 is 10.620584964752197 sec
#
# Time taken for epoch 85 is 10.704315900802612 sec
#
# Time taken for epoch 86 is 10.62297797203064 sec
#
# Time taken for epoch 87 is 10.64121699333191 sec
#
# Time taken for epoch 88 is 10.653385162353516 sec
#
# Time taken for epoch 89 is 10.664041996002197 sec
#
# Time taken for epoch 90 is 10.700303077697754 sec
#
# Time taken for epoch 91 is 10.613651990890503 sec
#
# Time taken for epoch 92 is 10.614702224731445 sec
#
# Time taken for epoch 93 is 10.649919033050537 sec
#
# Time taken for epoch 94 is 10.668376207351685 sec
#
# Time taken for epoch 95 is 10.719871044158936 sec
#
# Time taken for epoch 96 is 11.840481042861938 sec
#
# Time taken for epoch 97 is 12.188825845718384 sec
#
# Time taken for epoch 98 is 11.57567310333252 sec
#
# Time taken for epoch 99 is 13.113456964492798 sec
# Time taken for epoch 100 is 12.576658964157104 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 6
#       3 start = time.time()
#       5 for iteration in range(iterations):
# ----> 6     cond_gan.train_step(all_data, batch_size)
#       8 if (epoch + 1) % 50 == 0:
#       9     generate_images(generator, epoch, z_dim)
#
# Cell In[20], line 76, in ConditionalGAN.train_step(self, data, batch_size)
#      73     g_loss = self.loss_fn(misleading_labels, predictions)
#      75 grads = tape.gradient(g_loss, self.generator.trainable_weights)
# ---> 76 self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))
#      78 # Monitor loss.
#      79 self.gen_loss_tracker.update_state(g_loss)
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py:672, in OptimizerV2.apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     661 if (not experimental_aggregate_gradients and strategy and isinstance(
#     662     strategy,
#     663     (tf.compat.v1.distribute.experimental.ParameterServerStrategy,
#     664      tf.distribute.experimental.ParameterServerStrategy,
#     665      tf.distribute.experimental.CentralStorageStrategy,
#     666      tf.compat.v1.distribute.experimental.CentralStorageStrategy))):
#     667   raise NotImplementedError(
#     668       "`experimental_aggregate_gradients=False is not supported for "
#     669       "ParameterServerStrategy and CentralStorageStrategy. Used: "
#     670       f"strategy={strategy}.")
# --> 672 apply_state = self._prepare(var_list)
#     673 if experimental_aggregate_gradients:
#     674   grads_and_vars = self._transform_unaggregated_gradients(grads_and_vars)
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py:992, in OptimizerV2._prepare(self, var_list)
#     990   apply_state[(var_device, var_dtype)] = {}
#     991   with tf.device(var_device):
# --> 992     self._prepare_local(var_device, var_dtype, apply_state)
#     994 return apply_state
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:132, in Adam._prepare_local(self, var_device, var_dtype, apply_state)
#     129 def _prepare_local(self, var_device, var_dtype, apply_state):
#     130   super(Adam, self)._prepare_local(var_device, var_dtype, apply_state)
# --> 132   local_step = tf.cast(self.iterations + 1, var_dtype)
#     133   beta_1_t = tf.identity(self._get_hyper('beta_1', var_dtype))
#     134   beta_2_t = tf.identity(self._get_hyper('beta_2', var_dtype))
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/tensorflow/python/ops/variables.py:1074, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1072 def _run_op(a, *args, **kwargs):
#    1073   # pylint: disable=protected-access
# -> 1074   return tensor_oper(a.value(), *args, **kwargs)
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:1406, in _OverrideBinaryOperatorHelper.<locals>.binary_op_wrapper(x, y)
#    1401 try:
#    1402   # force_same_dtype=False to preserve existing TF behavior
#    1403   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1404   #   r_binary_op_wrapper use different force_same_dtype values.
#    1405   x, y = maybe_promote_tensors(x, y)
# -> 1406   return func(x, y, name=name)
#    1407 except (TypeError, ValueError) as e:
#    1408   # Even if dispatching the op failed, the RHS may be a tensor aware
#    1409   # object that can implement the operator with knowledge of itself
#    (...)
#    1412   # original error from the LHS, because it may be more
#    1413   # informative.
#    1414   if hasattr(type(y), "__r%s__" % op_name):
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:1756, in _add_dispatch(x, y, name)
#    1754   return gen_math_ops.add(x, y, name=name)
#    1755 else:
# -> 1756   return gen_math_ops.add_v2(x, y, name=name)
#
# File /opt/anaconda3/envs/gantest/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py:462, in add_v2(x, y, name)
#     460 if tld.is_eager:
#     461   try:
# --> 462     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     463       _ctx, "AddV2", name, x, y)
#     464     return _result
#     465   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print(generated_images.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(generated_images.shape)
#
# NameError: name 'generated_images' is not defined

# %%
a.shape

# %%
print(type(a))

# %%
print(all_label[301])

# %%
a = np.array([[1],[2],[3],[4]])

# %%
a.shape
